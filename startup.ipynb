# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
startup = pd.read_excel('datasets/startup-expansion.xlsx')
startup
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue
# 0               2601    48610
# 1               2727    45689
# 2               2768    49554
# ...

# %%
startup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Store ID         150 non-null    int64
#  1   City             150 non-null    object
#  2   State            150 non-null    object
#  3   Sales Region     150 non-null    object
#  4   New Expansion    150 non-null    object
#  5   Marketing Spend  150 non-null    int64
#  6   Revenue          150 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 8.3+ KB

# %%
startup[['Marketing Spend','Revenue']].describe().round(2)
# Out:
#        Marketing Spend   Revenue
# count           150.00    150.00
# mean           2893.15  39301.43
# std             367.86  15465.75
# min            1811.00  15562.00
# 25%            2662.25  21113.50
# 50%            2898.00  42993.00
# 75%            3111.50  51145.50
# max            3984.00  68828.00

# %%
len(startup['City'].value_counts())
# Out:
# 149

# %%
startup['City'].value_counts()
# Out:
# Rochester        2
# Killeen          1
# Wichita Falls    1
# Naperville       1
# Clovis           1
#                 ..
# Akron            1
# Fullerton        1
# Manchester       1
# Everett          1
# Thousand Oaks    1
# Name: City, Length: 149, dtype: int64

# %%
startup.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
startup.duplicated().sum()
# Out:
# 0

# %%
startup['City'].nunique()
# Out:
# 149

# %%
startup['City'].unique()
# Out:
# array(['Peoria', 'Midland', 'Spokane', 'Denton', 'Overland Park',
#        'Yonkers', 'Birmingham', 'Antioch', 'Worcester', 'Rochester',
#        'Rialto', 'Santa Maria', 'Las Cruces', 'Jackson', 'Hillsboro',
#        'Temecula', 'Tallahassee', 'Fontana', 'Kent', 'Broken Arrow',
#        'Concord', 'Modesto', 'Montgomery', 'Burbank', 'Elk Grove',
#        'Port St. Lucie', 'Elizabeth', 'Salt Lake City', 'Waco', 'Edison',
#        'Boulder', 'Grand Rapids', 'Tyler', 'Charleston', 'Huntsville',
#        'Pearland', 'Inglewood', 'Oxnard', 'Miramar', 'Cape Coral',
#        'Syracuse', 'Newport News', 'Lewisville', 'Carrollton',
#        'San Bernardino', 'Pasadena', 'Roseville', 'Murrieta',
#        'San Angelo', 'Olathe', 'Akron', 'Fullerton', 'Manchester',
#        'Everett', 'West Covina', 'Thornton', 'Hampton', 'Waterbury',
#        'Ventura', 'Davenport', 'Columbia', 'Simi Valley', 'Richmond',
#        'Little Rock', 'El Cajon', 'Santa Clara', 'Oceanside', 'Davie',
# ...

# %%
startup.isna()
# Out:
#      Store ID   City  State  Sales Region  New Expansion  Marketing Spend  \
# 0       False  False  False         False          False            False
# 1       False  False  False         False          False            False
# 2       False  False  False         False          False            False
# 3       False  False  False         False          False            False
# 4       False  False  False         False          False            False
# ..        ...    ...    ...           ...            ...              ...
# 145     False  False  False         False          False            False
# 146     False  False  False         False          False            False
# 147     False  False  False         False          False            False
# 148     False  False  False         False          False            False
# 149     False  False  False         False          False            False
#
#      Revenue
# 0      False
# 1      False
# 2      False
# 3      False
# ...

# %%
startup.isna().sum()
# Out:
# Store ID           0
# City               0
# State              0
# Sales Region       0
# New Expansion      0
# Marketing Spend    0
# Revenue            0
# dtype: int64

# %%
startup.sample(10)
# Out:
#      Store ID        City        State Sales Region New Expansion  \
# 17         18     Fontana   California     Region 2           Old
# 2           3     Spokane   Washington     Region 2           Old
# 74         75   Vancouver   Washington     Region 2           Old
# 122       123  Bridgeport  Connecticut     Region 1           Old
# 92         93       Elgin     Illinois     Region 1           Old
# 67         68       Davie      Florida     Region 1           Old
# 133       134   Green Bay    Wisconsin     Region 1           Old
# 18         19        Kent   Washington     Region 2           Old
# 93         94      Aurora     Illinois     Region 1           Old
# 104       105      Orange   California     Region 2           Old
#
#      Marketing Spend  Revenue
# 17              3085    63027
# 2               2768    49554
# 74              3329    58951
# 122             2914    47108
# 92              2553    18215
# 67              3177    45418
# ...

# %%
startup.groupby('State').sum()['Revenue'].nlargest(10)
# Out:
# C:\Users\Win 10\AppData\Local\Temp\ipykernel_10536\2550014485.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   startup.groupby('State').sum()['Revenue'].nlargest(10)
# State
# California     1504351
# Texas           640569
# Florida         479023
# Washington      298013
# Alabama         221025
# Illinois        200413
# New York        160046
# Connecticut     158511
# Georgia         157656
# Colorado        156495
# Name: Revenue, dtype: int64

# %%
startup[startup['New Expansion'] == 'Old'].groupby(['State','City']).sum()['Revenue'].nlargest(10)
# Out:
# C:\Users\Win 10\AppData\Local\Temp\ipykernel_10536\1581099464.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   startup[startup['New Expansion'] == 'Old'].groupby(['State','City']).sum()['Revenue'].nlargest(10)
# State          City
# Arkansas       Little Rock       68828
# Michigan       Grand Rapids      65475
# New York       Rochester         64906
# California     Oxnard            64302
#                Fontana           63027
# Rhode Island   Providence        62337
# Alabama        Birmingham        60338
# Kansas         Overland Park     59887
# California     San Bernardino    59870
# Massachusetts  Worcester         59840
# Name: Revenue, dtype: int64

# %%
startup[startup['New Expansion'] == 'New'].groupby(['State','City']).sum()['Revenue'].nlargest(10)
# Out:
# C:\Users\Win 10\AppData\Local\Temp\ipykernel_10536\1151625651.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   startup[startup['New Expansion'] == 'New'].groupby(['State','City']).sum()['Revenue'].nlargest(10)
# State       City
# Texas       Brownsville         63148
# Tennessee   Chattanooga         55357
# California  Rancho Cucamonga    52366
#             Glendale            49376
# Arizona     Tempe               48954
# Illinois    Joliet              48315
#             Rockford            43377
# California  Thousand Oaks       40141
# New Jersey  Paterson            34603
# Texas       College Station     22457
# Name: Revenue, dtype: int64

# %%
startup['Profit'] = startup['Revenue'] - startup['Marketing Spend']

# %%
startup
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue  Profit
# 0               2601    48610   46009
# 1               2727    45689   42962
# ...

# %%
startup['ROMS%'] = round(startup['Profit'] / startup['Marketing Spend'] ,2)

# %%
startup
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue  Profit  ROMS%
# 0               2601    48610   46009  17.69
# ...

# %%
startup.to_csv('startup-modified.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 start
#
# NameError: name 'start' is not defined
